# %%
import csv
import numpy as np


def create_real_array(exist_file_name): #создаем проверочный массив из существующего csv
        real_array = []
        with open(exist_file_name, 'r') as file_obj:
            reader = csv.reader(file_obj)
            for row in reader:
                real_array.append(row)
        for row_num in range(len(real_array)): #приводим дату к нормальному формату
            date = real_array[row_num][0]
            right_date = '{}{}.{}{}.20{}{}'
            real_array[row_num][0] = right_date.format(*date)
        #print(real_file_name, real_array)
        return real_array


def create_prediction_array(file_path): #создаем проверяемый массив
    with open(file_path, 'r') as fp:
        reader = csv.reader(fp)

        prepeare_list = []
        t_list = []
        d_list = []
        lpr_list = []
        lp = []
        hpr_list = []
        c_list = []
        prediction = []
        a = 1
        for i in reader:
            prepeare_list.append(i)

        for each in prepeare_list:
            if a == 1:
                t_list = t_list + each
            if a == 2:
                d_list = d_list + each
            if a == 3:
                lpr_list = lpr_list + each
            if a == 4:
                hpr_list = hpr_list + each
            if a == 5:
                c_list = c_list + each
            a = a + 1
            if a == 6:
                a = 1

        for each in lpr_list:
            if each != '':
                lp.append(each)
            else:
                lp.append(1)

        prediction.append(t_list)
        prediction.append(d_list)
        prediction.append(lp)
        prediction.append(hpr_list)
        prediction.append(c_list)

    return prediction

def create_prediction_data(prediction_array, num): #создаем 1 запись из проверяемого массива
    ticker = prediction_array[0][num]
    date = prediction_array[1][num]
    invest_horizont = prediction_array[2][num]
    prediction_price = prediction_array[3][num]
    prediction_action = prediction_array[4][num]

    return {'ticker': ticker,
            'date': date,
            'invest_horizont': invest_horizont,
            'prediction_price': prediction_price,
            'prediction_action': prediction_action}

def find_true_csv(real_file_name):  #ищем по тикерам *.csv-файлы, по которым будем проверять записи
    not_exist = 0
    try:
        with open(real_file_name, 'r') as true_csv:
            return real_file_name
    except:
        not_exist = []
        return print(real_file_name + ' is not exist')
        #not_exist.append(real_file_name)

def find_data(prediction_dict, real_array): #ищем в проверяющем массиве строку, в которой совпадает дата с проверяемой записью
    num_row = 0
    f_num_row = 0
    for row in real_array:
        if prediction_dict['date'] == row[0]:
            f_num_row = num_row
        num_row += 1
    return int(f_num_row)

def comparison(num_row, prediction_dict, real_array):  #сравниваем проверяемую запись с проверяющим массивом по нужным датам начиная со строки, на которой даты совпали
    if prediction_dict['prediction_action']=='Покупать':
        for row in real_array[num_row : int(prediction_dict['invest_horizont']) + int(num_row)]:
            if prediction_dict['prediction_price'] >= row[3]:
                result_ticker.append(prediction_dict['ticker'])
                result_prediction.append(True)
                break
        else:
                result_ticker.append(prediction_dict['ticker'])
                result_prediction.append(False)
        result_array = stack_array(result_ticker, result_prediction)
    else:
        for row in real_array[num_row: num_row + int(prediction_dict['invest_horizont'])]:
            if prediction_dict['prediction_price'] <= row[3]:
                result_ticker.append(prediction_dict['ticker'])
                result_prediction.append(True)
                break
        else:
                result_ticker.append(prediction_dict['ticker'])
                result_prediction.append(False)
        result_array = stack_array(result_ticker, result_prediction)
    return result_array

def stack_array(*arrays):
    data = np.stack(arrays)
    return data

if __name__ == '__main__':
    file_path = 'prediction_all.csv' # путь к проверяемому файлу
    prediction_array = create_prediction_array(file_path)  # создаем проверяемый массив
    result_ticker = []
    result_prediction = []
    result_array = []   # создаем массив с результатами
    for num in range(len(prediction_array[0])):  # перебираем поочереди записи в проверяемом массиве
        prediction_dict = create_prediction_data(prediction_array, num)  # создаем проверяемую запись
        real_file_name = prediction_dict['ticker'] + '.csv' #создаем имя проверяющего файла из названия тикера в проверяемой записи
        exist_file_name = find_true_csv(real_file_name)  # создаем имф файла, который точно существуют

        if exist_file_name:            # из файла который точно существует
            real_array = create_real_array(exist_file_name)   #создаем проверяющий массив
            num_row_of_date = find_data(prediction_dict, real_array)  # находим номер строки в проверяющем массиве, на которой совпадают даты с проверяемой записью
            result_array = comparison(num_row_of_date, prediction_dict, real_array)  #сравниваем и записываем в массив с результатами название тикера и результат проверки

    
    print(result_array)
# Out:
# SIM8.csv is not exist
# GDM8.csv is not exist
# SIM8.csv is not exist
# BRK-8.csv is not exist
# BRM8.csv is not exist
# RIM8.csv is not exist
# BRN8.csv is not exist
# Х.csv is not exist
# SIM8.csv is not exist
# BRN8.csv is not exist
# BRN8.csv is not exist
# MMK.csv is not exist
# GDU8.csv is not exist
# RIU8.csv is not exist
# RTN.csv is not exist
# SIU8.csv is not exist
# QCOM.csv is not exist
# BRU8.csv is not exist
# YUM.csv is not exist
# USD_RUB_TOM.csv is not exist
# RIU8.csv is not exist
# MCD.csv is not exist
# BANE.csv is not exist
# TSLA.csv is not exist
# GD.csv is not exist
# FEES.csv is not exist
# PX.csv is not exist
# USU8.csv is not exist
# SQ.csv is not exist
# BA.csv is not exist
# OGKB.csv is not exist
# JPM.csv is not exist
# GDU8.csv is not exist
# HYDR.csv is not exist
# X.csv is not exist
# SIM8.csv is not exist
# WU.csv is not exist
# AXP.csv is not exist
# SIU8.csv is not exist
# APPL.csv is not exist
# GAZR.csv is not exist
# SiZ8.csv is not exist
# BRV8.csv is not exist
# MCD.csv is not exist
# NKE.csv is not exist
# SiZ8.csv is not exist
# KORS.csv is not exist
# STZ.csv is not exist
# RIZ8.csv is not exist
# TRNFPS.csv is not exist
# IBM.csv is not exist
# MS.csv is not exist
# JD.csv is not exist
# TWTR.csv is not exist
# DB.csv is not exist
# FEES.csv is not exist
# BIIB.csv is not exist
# TSLA.csv is not exist
# SIZ8.csv is not exist
# RIZ8.csv is not exist
# BRZ8.csv is not exist
# KO.csv is not exist
# FCX.csv is not exist
# Si-12.18.csv is not exist
# SQ.csv is not exist
# SQ.csv is not exist
# V.csv is not exist
# BRF-9.csv is not exist
# DB.csv is not exist
# SIZ8.csv is not exist
# MDT.csv is not exist
# LTM.csv is not exist
# BRF9.csv is not exist
# VTB.csv is not exist
# BA.csv is not exist
# BRF9.csv is not exist
# QCOM.csv is not exist
# HYDR.csv is not exist
# BRG9.csv is not exist
# MS.csv is not exist
# PG.csv is not exist
# FEES.csv is not exist
# MSNG.csv is not exist
# MCD.csv is not exist
# LSNG.csv is not exist
# V.csv is not exist
# SiH9.csv is not exist
# HYDR.csv is not exist
# CAT.csv is not exist
# JPM.csv is not exist
# AMD.csv is not exist
# RTS-3.19.csv is not exist
# IBM.csv is not exist
# RIH9.csv is not exist
# ADBE.csv is not exist
# SBUX.csv is not exist
# SIH9.csv is not exist
# SQ.csv is not exist
# GAZ.csv is not exist
# TEVA.csv is not exist
# TSLA.csv is not exist
# EA.csv is not exist
# BRH9.csv is not exist
# WB.csv is not exist
# NTAP.csv is not exist
# SIH9.csv is not exist
# TSLA.csv is not exist
# FIVE-гдр.csv is not exist
# KO.csv is not exist
# BRH9.csv is not exist
# WB.csv is not exist
# LTM.csv is not exist
# RIH9.csv is not exist
# BKNG.csv is not exist
# GDH9.csv is not exist
# BA.csv is not exist
# AMD.csv is not exist
# EURRUB_TOM.csv is not exist
# BOE.csv is not exist
# RIH9.csv is not exist
# JPM.csv is not exist
# TSLA.csv is not exist
# BSPB.csv is not exist
# TLRY.csv is not exist
# AMD.csv is not exist
# JPM.csv is not exist
# JCP.csv is not exist
# MCD.csv is not exist
# BA.csv is not exist
# MSNG.csv is not exist
# EA.csv is not exist
# TSLA.csv is not exist
# CCL.csv is not exist
# TSLA.csv is not exist
# JNJ.csv is not exist
# MSTT.csv is not exist
# HYDR.csv is not exist
# LSRG.csv is not exist
# HAL.csv is not exist
# DB.csv is not exist
# SIM9.csv is not exist
# AIG.csv is not exist
# AAL.csv is not exist
# LUKH.csv is not exist
# BA.csv is not exist
# QCOM.csv is not exist
# MOS.csv is not exist
# DDD.csv is not exist
# TSLA.csv is not exist
# US500.csv is not exist
# SBERP.csv is not exist
# HYDR.csv is not exist
# NKE.csv is not exist
# BRN9.csv is not exist
# SIM9.csv is not exist
# USM9.csv is not exist
# MMU9.csv is not exist
# GDM9.csv is not exist
# FCX.csv is not exist
# BOE.csv is not exist
# MTCH.csv is not exist
# USU9.csv is not exist
# JNJ.csv is not exist
# BRQ9.csv is not exist
# SHOP.csv is not exist
# ACN.csv is not exist
# RIU9.csv is not exist
# SiU9.csv is not exist
# TSLA.csv is not exist
# KHC.csv is not exist
# CVX.csv is not exist
# OGKB.csv is not exist
# BRQ9.csv is not exist
# JNJ.csv is not exist
# JPM.csv is not exist
# EDU9.csv is not exist
# UAL.csv is not exist
# IBM.csv is not exist
# MSFT.csv is not exist
# ORCL.csv is not exist
# POLY.csv is not exist
# BOE.csv is not exist
# RUAL.csv is not exist
# FMC.csv is not exist
# UPRO.csv is not exist
# COF.csv is not exist
# BKNG.csv is not exist
# UPRO.csv is not exist
# VZ.csv is not exist
# VTB.csv is not exist
# KHC.csv is not exist
# JNJ.csv is not exist
# BA.csv is not exist
# VTB.csv is not exist
# ROST.csv is not exist
# LOW.csv is not exist
# USU9.csv is not exist
# SIU9.csv is not exist
# UAA.csv is not exist
# MTCH.csv is not exist
# CPB.csv is not exist
# SiZ9.csv is not exist
# AFKS.csv is not exist
# MTCH.csv is not exist
# GDZ9.csv is not exist
# Т.csv is not exist
# TGKA.csv is not exist
# BSPB.csv is not exist
# SHOP.csv is not exist
# SIZ9.csv is not exist
# MSFT.csv is not exist
# GLPR.csv is not exist
# AFKS.csv is not exist
# POLY.csv is not exist
# PM.csv is not exist
# GDZ9.csv is not exist
# SBERP.csv is not exist
# PANW.csv is not exist
# SQ.csv is not exist
# HYDR.csv is not exist
# USZ9.csv is not exist
# MMZ9.csv is not exist
# GDZ9.csv is not exist
# AFKS.csv is not exist
# IBM.csv is not exist
# TRMK.csv is not exist
# WB.csv is not exist
# HAL.csv is not exist
# SQ.csv is not exist
# DSKY.csv is not exist
# MSNG.csv is not exist
# RUAL.csv is not exist
# TWTR.csv is not exist
# OGKB.csv is not exist
# SiZ9.csv is not exist
# BRK.B.csv is not exist
# CL.csv is not exist
# MOS.csv is not exist
# BA.csv is not exist
# MTLR.csv is not exist
# AAL.csv is not exist
# WB.csv is not exist
# FEES.csv is not exist
# WM.csv is not exist
# RCL.csv is not exist
# BRZ9.csv is not exist
# REGN.csv is not exist
# TRMK.csv is not exist
# NKE.csv is not exist
# PG.csv is not exist
# AFKS.csv is not exist
# ABBV.csv is not exist
# TCSG.csv is not exist
# GDZ9.csv is not exist
# NOW.csv is not exist
# MMZ9.csv is not exist
# NTNX.csv is not exist
# BIDU.csv is not exist
# V.csv is not exist
# BRF0.csv is not exist
# AFKS.csv is not exist
# SWN.csv is not exist
# BA.csv is not exist
# BRF0.csv is not exist
# BANEP.csv is not exist
# MSFT.csv is not exist
# ORCL.csv is not exist
# SiH0.csv is not exist
# SLB.csv is not exist
# DSKY.csv is not exist
# MCD.csv is not exist
# BA.csv is not exist
# USDRUB_TOM.csv is not exist
# KO.csv is not exist
# SBERP.csv is not exist
# NKE.csv is not exist
# SIH0.csv is not exist
# SNGS.csv is not exist
# SVH0.csv is not exist
# FFIV.csv is not exist
# PTH0.csv is not exist
# NOK.csv is not exist
# SIH0.csv is not exist
# HYDR.csv is not exist
# MOS.csv is not exist
# AMAT.csv is not exist
# HYDR.csv is not exist
# BRG0.csv is not exist
# TSLA.csv is not exist
# SIH0.csv is not exist
# TGKA.csv is not exist
# HAL.csv is not exist
# bidu.csv is not exist
# BA.csv is not exist
# RIH0.csv is not exist
# SQ.csv is not exist
# FEES.csv is not exist
# GLD.csv is not exist
# DSKY.csv is not exist
# MCD.csv is not exist
# MLTR.csv is not exist
# AMD.csv is not exist
# BRH0.csv is not exist
# COTY.csv is not exist
# Cisco.csv is not exist
#  JNJ .csv is not exist
# RUAL.csv is not exist
# GILD.csv is not exist
# EDH0.csv is not exist
# VLO.csv is not exist
# J.csv is not exist
# AGN.csv is not exist
# TRMK.csv is not exist
# BSX.csv is not exist
# BRH0.csv is not exist
# SVH0.csv is not exist
# BMY.csv is not exist
# EXC.csv is not exist
# CVX.csv is not exist
# bidu.csv is not exist
# SiH0.csv is not exist
# ENRU.csv is not exist
# POLY.csv is not exist
# UPRO.csv is not exist
# MSFT.csv is not exist
# GDH0.csv is not exist
# AMD.csv is not exist
# BRJ0.csv is not exist
# MOS.csv is not exist
# TCSq.csv is not exist
# TSN.csv is not exist
# SIM0.csv is not exist
# KO.csv is not exist
# EDM0.csv is not exist
# BA.csv is not exist
# SIM0.csv is not exist
# AMAT.csv is not exist
# GDM0.csv is not exist
# RIM0.csv is not exist
# ZM.csv is not exist
# KO.csv is not exist
# EDM0.csv is not exist
# CVX.csv is not exist
# ZM.csv is not exist
# EDM0.csv is not exist
# AUM0.csv is not exist
# V.csv is not exist
# SIM0.csv is not exist
# BRK0.csv is not exist
# AKAM.csv is not exist
# JPM.csv is not exist
# RIM0.csv is not exist
# AUM0.csv is not exist
# PG.csv is not exist
# BRK0.csv is not exist
# GILD.csv is not exist
# PM.csv is not exist
# SVM0.csv is not exist
# DD.csv is not exist
# UBER.csv is not exist
# SBUX.csv is not exist
# APA.csv is not exist
# RIM0.csv is not exist
# HAS.csv is not exist
# Т.csv is not exist
# SIM0.csv is not exist
# М.csv is not exist
# SIN0.csv is not exist
# CVX.csv is not exist
# BMY.csv is not exist
# RIM0.csv is not exist
# ALXN.csv is not exist
# COTY.csv is not exist
# NDAQ.csv is not exist
# MPC.csv is not exist
# JPM.csv is not exist
# ENPG.csv is not exist
# ВА.csv is not exist
# AMAT.csv is not exist
# MXM0.csv is not exist
# ВАС.csv is not exist
# MRNA.csv is not exist
# HWM.csv is not exist
# MUR.csv is not exist
# ZM.csv is not exist
# SIM0.csv is not exist
# GMK.csv is not exist
# MSFT.csv is not exist
# BSPB.csv is not exist
# CAT.csv is not exist
# SNGS.csv is not exist
# BRN0.csv is not exist
# ADBE.csv is not exist
# BANEP.csv is not exist
# AAL.csv is not exist
# AFKS.csv is not exist
# AMD.csv is not exist
# LSRG.csv is not exist
# APTV.csv is not exist
# ADBE.csv is not exist
# FEES.csv is not exist
# GLD.csv is not exist
# LUKH.csv is not exist
# D.csv is not exist
# CIEN.csv is not exist
# SIU0.csv is not exist
# XLNX.csv is not exist
# GDU0.csv is not exist
# CVX.csv is not exist
# LUKH.csv is not exist
#  JPM.csv is not exist
# BRQ0.csv is not exist
# DBX.csv is not exist
# RIU0.csv is not exist
# MSFT.csv is not exist
# [['AFLT' 'NVTK' 'AAPL' ... 'AAPL' 'GS' 'ROSN']
#  ['True' 'False' 'True' ... 'True' 'True' 'True']]

# %%
counts = np.unique(result_array[1], return_counts=True)
count_false = counts[1][0]
count_true = counts[1][1]
precent_of_true_predict = print("Правильность предсказаний равна =", "{:.0%}".format(count_true/(count_true+count_false)))
# precent_of_true_predict
# Out:
# Правильность предсказаний равна = 80%

# %%
counts = np.unique(result_array[1], return_counts=True)
count_false = counts[1][0]
count_true = counts[1][1]
precent_of_true_predict = print("Правильность предсказаний равна =", "{:.0%}".format(count_true/(count_true+count_false)))
# precent_of_true_predict
# Out:
# Правильность предсказаний равна = 77%
